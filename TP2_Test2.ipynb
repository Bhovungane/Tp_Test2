# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\27797\Desktop\TP2_Test2\Informal_Settlement_Programme_-1898186875815614491.csv")

# %%
print(df.columns)
# Out:
# Index(['OBJECTID', 'NAME_OF_SE', 'ALT_NAME', 'STREETNAME', 'WARD_S',
#        'PLANNING_U', 'LATITUDE', 'LONGITUDE', 'REGION', 'WATER_SUPP',
#        'SANITATION', 'REFUSE', 'ELECTRIC_2', 'UNIREFCODE', 'EST_HHC',
#        'NUSP_CAT', 'Shape__Area', 'Shape__Length'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    OBJECTID     NAME_OF_SE       ALT_NAME  \
# 0         1       Amatikwe
# 1         2  Congo Phase 2  Congo Phase 2
# 2         3  Africa Inanda         Africa
# 3         4        Namibia
# 4         5     Mshayazafe
#
#                                STREETNAME  WARD_S  \
# 0                              MR93 North  56/108
# 1                        MR93 /MR93 North   55/57
# 2                  Curnick Ndlovu Highway      55
# 3  Curnick Ndlovu Highway / Matshana Road  108/44
# 4                            Sidudla Road      55
#
#                       PLANNING_U  LATITUDE  LONGITUDE    REGION  \
# 0                       Amatikwe  0.768286   0.587262  Northern
# 1                   Inanda Congo  0.756247   0.619781  Northern
# 2        Ohlange-Africa / Stop 8  0.745458   0.613385  Northern
# 3                 Inanda Namibia  0.740700   0.587773  Northern
# 4  Mshayazafe / Ohlange - Africa  0.736482   0.610517  Northern
#
# ...

# %% [markdown]
# This dataset is suitable for analysis and i took it from website
# #Data Completeness#
#
# The dataset includes multiple columns that cover various aspects of informal settlements, such as population density, access to services, and housing conditions.
# The data is comprehensive, offering a detailed snapshot of the living conditions within Nairobi's informal settlements.
#
# #Relevance#
#
# Population Density: This column provides information on the number of people living in a given area, which is crucial for understanding the extent and impact of informal settlements.
# Access to Services: This column includes data on the availability of essential services such as water, sanitation, and electricity, which are key indicators of the living standards and challenges faced by residents of informal settlements.
# These columns are directly relevant to the theme of informal settlements, as they address critical aspects of life within these communities.
#
# #Credibility of the Source#
#
# The dataset is provided by the Humanitarian Data Exchange (HDX), a reputable platform managed by the United Nations OCHA, ensuring the reliability and credibility of the data.
# The data has likely been collected and

# %%
# Print the shape of the dataset (number of rows and columns)
print("\nShape of the dataset:")
print(df.shape)
# Out:
# Shape of the dataset:
# (566, 18)

# %%
# Print the data types of each column
print("\nData types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# OBJECTID           int64
# NAME_OF_SE        object
# ALT_NAME          object
# STREETNAME        object
# WARD_S            object
# PLANNING_U        object
# LATITUDE          object
# LONGITUDE         object
# REGION            object
# WATER_SUPP        object
# SANITATION        object
# REFUSE            object
# ELECTRIC_2        object
# UNIREFCODE        object
# EST_HHC            int64
# NUSP_CAT          object
# Shape__Area      float64
# Shape__Length    float64
# dtype: object

# %%
 #Print a summary of the dataset#
print("\nSummary of the dataset:")
print(df.describe(include='all'))
# Out:
# Summary of the dataset:
#         OBJECTID NAME_OF_SE ALT_NAME            STREETNAME WARD_S PLANNING_U  \
# count   566.0000        566      562                   566    566        566
# unique       NaN        566      250                   503    152        230
# top          NaN   Amatikwe           District Road No.403     83   Clermont
# freq         NaN          1      305                     8     28         18
# mean    283.5000        NaN      NaN                   NaN    NaN        NaN
# std     163.5344        NaN      NaN                   NaN    NaN        NaN
# min       1.0000        NaN      NaN                   NaN    NaN        NaN
# 25%     142.2500        NaN      NaN                   NaN    NaN        NaN
# 50%     283.5000        NaN      NaN                   NaN    NaN        NaN
# 75%     424.7500        NaN      NaN                   NaN    NaN        NaN
# max     566.0000        NaN      NaN                   NaN    NaN        NaN
#
# ...

# %%
# Print the column names
print("\nColumn names:")
print(df.columns)
# Out:
# Column names:
# Index(['OBJECTID', 'NAME_OF_SE', 'ALT_NAME', 'STREETNAME', 'WARD_S',
#        'PLANNING_U', 'LATITUDE', 'LONGITUDE', 'REGION', 'WATER_SUPP',
#        'SANITATION', 'REFUSE', 'ELECTRIC_2', 'UNIREFCODE', 'EST_HHC',
#        'NUSP_CAT', 'Shape__Area', 'Shape__Length'],
#       dtype='object')

# %%
# Identifying missing data#
print("\nMissing data in each column:")
print(df.isnull().sum())
# Out:
# Missing data in each column:
# OBJECTID         0
# NAME_OF_SE       0
# ALT_NAME         4
# STREETNAME       0
# WARD_S           0
# PLANNING_U       0
# LATITUDE         0
# LONGITUDE        0
# REGION           0
# WATER_SUPP       0
# SANITATION       0
# REFUSE           0
# ELECTRIC_2       0
# UNIREFCODE       0
# EST_HHC          0
# NUSP_CAT         0
# Shape__Area      0
# Shape__Length    0
# dtype: int64

# %%
df['LATITUDE'] = df['LATITUDE'].str.replace(',', '.').astype(float)
df['LONGITUDE'] = df['LONGITUDE'].str.replace(',', '.').astype(float)

# Normalize 'LATITUDE' and 'LONGITUDE' columns
scaler = MinMaxScaler()
df[['LATITUDE', 'LONGITUDE']] = scaler.fit_transform(df[['LATITUDE', 'LONGITUDE']])

print("\nFirst few rows of the dataset after normalization:")
print(df.head())
# Out:
# First few rows of the dataset after normalization:
#    OBJECTID     NAME_OF_SE       ALT_NAME  \
# 0         1       Amatikwe
# 1         2  Congo Phase 2  Congo Phase 2
# 2         3  Africa Inanda         Africa
# 3         4        Namibia
# 4         5     Mshayazafe
#
#                                STREETNAME  WARD_S  \
# 0                              MR93 North  56/108
# 1                        MR93 /MR93 North   55/57
# 2                  Curnick Ndlovu Highway      55
# 3  Curnick Ndlovu Highway / Matshana Road  108/44
# 4                            Sidudla Road      55
#
#                       PLANNING_U  LATITUDE  LONGITUDE    REGION  \
# 0                       Amatikwe  0.768286   0.587262  Northern
# 1                   Inanda Congo  0.756247   0.619781  Northern
# 2        Ohlange-Africa / Stop 8  0.745458   0.613385  Northern
# 3                 Inanda Namibia  0.740700   0.587773  Northern
# 4  Mshayazafe / Ohlange - Africa  0.736482   0.610517  Northern
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Basic Infographic Charts

# Bar chart: Population Density by Region
plt.figure(figsize=(10, 6))
sns.barplot(x='REGION', y='LATITUDE', data=df, ci=None)
plt.title(' LATITUDE')
plt.xlabel('REGION')
plt.ylabel('LATITUDE')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\27797\AppData\Local\Temp\ipykernel_16548\207691510.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='REGION', y='LATITUDE', data=df, ci=None)

# %%
# Histogram: Distribution of Population Density
plt.figure(figsize=(10, 6))
sns.histplot(df['LATITUDE'], bins=20, kde=True)
plt.title('Distribution of LATITUDE')
plt.xlabel('LATITUDE (people per sq km)')
plt.ylabel('Frequency')
plt.show()

# %%
# Count the occurrences of each sanitation type
sanitation_counts = df['SANITATION'].loc[100:109].value_counts()

# Plot a pie chart for sanitation types
plt.figure(figsize=(8, 8))
plt.pie(sanitation_counts, labels=sanitation_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Sanitation Types Distribution')
plt.show()

# %%
# Example: Plotting 'Population_Density' by 'Region' using a violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(x='REGION', y='LATITUDE', data=df)
plt.title('Population Density Distribution by Region (Violin Plot)')
plt.xticks(rotation=45)
plt.show()

# %%
# Select numeric columns for pairplot
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Plot pairplot
sns.pairplot(df[numeric_columns])
plt.title('Pairplot of Numeric Features')
plt.show()

# %%
# Additional Analysis: Highlighting significant patterns
# Finding regions with the highest population density
highest_density_region = df.groupby('Region')['LATITUDE'].mean().idxmax()
highest_density_value = df.groupby('Region')['LATITUDE'].mean().max()
print(f"\nRegion with the highest LATITUDE: {highest_density_region} ({highest_density_value:.2f} people per sq km)")

# Finding regions most lacking in basic services (e.g., water)
lowest_water_access_region = df.groupby('Region')['LATITUDE'].mean().idxmin()
lowest_water_access_value = df.groupby('Region')['LATITUDE'].mean().min()
print(f"Region most lacking in water access: {lowest_latitude_region} ({lowest_water_access_value:.2f})")

# Correlations between variables
correlation_with_population_density = cor.sort_values(ascending=False)
print("\nCorrelations with LATITUDE:")
print(correlation_with_population_density)

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]

# Example usage with 'EST_HHC' column
est_hhc_column = df['EST_HHC'].tolist()  # Extract 'EST_HHC' column from DataFrame
bubble_sort(est_hhc_column)
print("Sorted EST_HHC (ascending):", est_hhc_column)
# Out:
# Sorted EST_HHC (ascending): [4, 4, 4, 5, 5, 5, 8, 8, 8, 10, 10, 11, 11, 12, 12, 12, 12, 13, 13, 13, 14, 14, 14, 15, 15, 16, 16, 16, 16, 16, 17, 18, 18, 19, 19, 20, 21, 21, 21, 21, 22, 22, 23, 23, 23, 23, 23, 23, 24, 24, 24, 24, 24, 25, 25, 26, 26, 27, 27, 27, 27, 28, 28, 28, 28, 28, 29, 29, 29, 29, 29, 30, 30, 30, 31, 31, 31, 31, 32, 33, 33, 33, 34, 34, 34, 35, 35, 35, 35, 35, 35, 35, 35, 36, 36, 37, 37, 39, 39, 40, 40, 40, 41, 41, 42, 42, 42, 43, 43, 44, 45, 46, 46, 46, 46, 46, 46, 47, 48, 48, 48, 49, 49, 49, 50, 50, 50, 51, 51, 52, 52, 53, 53, 54, 54, 54, 55, 55, 56, 56, 57, 57, 57, 57, 57, 57, 58, 59, 60, 60, 60, 60, 60, 61, 61, 61, 61, 62, 63, 63, 63, 64, 64, 65, 65, 65, 66, 67, 67, 67, 68, 68, 70, 70, 70, 72, 72, 72, 74, 74, 74, 75, 76, 77, 77, 79, 79, 79, 80, 80, 80, 81, 81, 82, 84, 84, 84, 85, 86, 86, 87, 88, 89, 89, 90, 92, 93, 93, 94, 97, 98, 99, 100, 100, 101, 102, 103, 104, 106, 106, 107, 107, 111, 111, 112, 115, 115, 115, 116, 116, 117, 117, 117, 119, 119, 121, 122, 122, 
# ...

# %%
# Linear Search
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1  # Element not found

# Binary Search (Assuming 'arr' is sorted)
def binary_search(arr, target):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1  # Element not found

# Example usage with 'EST_HHC' column
est_hhc_column = sorted(df['EST_HHC'].tolist())  # Sort 'EST_HHC' column
target = 500  # Example target value

# Perform linear search
linear_result = linear_search(est_hhc_column, target)
if linear_result != -1:
    print(f"Linear Search: Found at index {linear_result}")
else:
    print("Linear Search: Element not found")

# Perform binary search
binary_result = binary_search(est_hhc_column, target)
if binary_result != -1:
    print(f"Binary Search: Found at index {binary_result}")
else:
    print("Binary Search: Element not found")
# Out:
# Linear Search: Element not found
# Binary Search: Element not found

# %%
### Complexity Analysis: Binary Search Algorithm

#### Time Complexity:
- Binary search has a time complexity of O(log n), where n is the number of elements in the dataset.
- In each iteration, binary search divides the dataset in half, effectively reducing the search space by half.
- As a result, the number of comparisons needed to find the target element grows logarithmically with the size of the dataset.
- This logarithmic growth rate makes binary search extremely efficient for large datasets compared to linear search, especially when the dataset is sorted.

#### Space Complexity:
- Binary search has a space complexity of O(1), which means it uses constant space regardless of the size of the dataset.
- It only requires a few extra variables for storing indices and temporary values, regardless of the size of the dataset.
- Binary search does not require any additional memory allocation proportional to the size of the dataset, making it memory-efficient.

#### Efficiency:
- The efficiency of binary search is remarkable, especially for large datasets.
- Its logarithmic time complexity ensures fast search performance even with exponentially increasing dataset sizes.
- By dividing the dataset in half at each step, binary search quickly narrows down the search space, making it much faster than linear search, particularly for large datasets.
- Binary search's constant space complexity also contributes to its efficiency, as it minimizes memory usage and overhead.
- Overall, binary search is one of the most efficient search algorithms, particularly when dealing with sorted datasets.
